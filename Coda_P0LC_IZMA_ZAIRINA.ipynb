# %% [markdown]
# <a href="https://colab.research.google.com/github/izmazrn/CODA_11_GIT/blob/main/Coda_P0LC_IZMA_ZAIRINA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# /*
# P0LC1
# Nama: IZMA ZAIRINA
# Batch: RMT-001
# */
#
# --Nomor 1
# SELECT * from TBL;
#
# --Nomor 2
# SELECT DISTINCT(row) from TBL as t;

# %%
from google.colab import auth
from google.cloud import bigquery
auth.authenticate_user()
print('authenticated')

project_id_akun = 'disco-module-472609-j6'
client = bigquery.Client(project=project_id_akun)
# Out:
# authenticated

# %%
df = client.query(
    '''
    select * from `bigquery-public-data.san_francisco_bikeshare.bikeshare_regions`;
    '''
).to_dataframe()

df
# Out:
#    region_id           name
# 0          3  San Francisco
# 1          5       San Jose
# 2         12        Oakland
# 3         13     Emeryville
# 4         14       Berkeley
# 5         23             8D

# %%
df = client.query(
    '''
    select * from `bigquery-public-data.san_francisco_bikeshare.bikeshare_station_info`;
    '''
).to_dataframe()

df
# Out:
#     station_id                                               name short_name  \
# 0          523        Lafayette Park (Laguna St at Washington St)     SF-E21
# 1          501  Balboa Park (San Jose Ave at Sgt. John V. Youn...     SF-Y16
# 2          504                       Onondaga Ave at Alemany Blvd    SF-AA17
# 3          539                    North Point St at Divisadero St     SF-A18
# 4          535                          Filbert St at Fillmore St     SF-C19
# ..         ...                                                ...        ...
# 467        266                             Parker St at Fulton St      BK-F8
# 468        250                        North Berkeley BART Station      BK-C5
# 469        246                              Berkeley Civic Center    BK-D7-2
# 470        245                             Downtown Berkeley BART    BK-D7-1
# 471        243                        Bancroft Way at College Ave     BK-D10
#
# ...

# %%
df = client.query(
    '''
    select * from `bigquery-public-data.san_francisco_bikeshare.bikeshare_station_status`;
    '''
).to_dataframe()

df
# Out:
#                                station_id  num_bikes_available  \
# 0    0d730ac1-7ce6-45cf-aca6-b412ea46709d                    0
# 1    28988488-fb74-4bbc-9e69-613698b2dd8c                    0
# 2    ab03623f-6fe9-4e9b-b38b-6e98513082d1                    0
# 3                     1950739878248286808                    0
# 4    e98999ee-5c3d-48b8-8735-baf6518ad915                    0
# ..                                    ...                  ...
# 583  e5b0aca4-2ce6-49f8-82e8-8eed6e004147                   28
# 584  94c877d2-f064-4373-b372-3f8997a07f30                   31
# 585  1af8102a-589a-47ea-97ec-4589b71403aa                   22
# 586  a646ab7e-7396-4009-abb8-0b51171325ff                   25
# 587  b2e9118f-aafb-49fb-b237-4ba08e21f51f                   36
#
#      num_bikes_disabled  num_docks_available  num_docks_disabled  \
# 0                     9                    0                   0
# 1                     0                   23                   0
# ...

# %%
df = client.query(
    '''
    select * from `bigquery-public-data.san_francisco_bikeshare.bikeshare_trips`;
    '''
).to_dataframe()

df
# Out:
#                     trip_id  duration_sec                start_date  \
# 0        201801111613101305           858 2018-01-11 16:13:10+00:00
# 1        201708052259011980          1480 2017-08-05 22:59:01+00:00
# 2        201711291820182717           783 2017-11-29 18:20:18+00:00
# 3        201710211842242521          1638 2017-10-21 18:42:24+00:00
# 4         20180213172604826          1066 2018-02-13 17:26:04+00:00
# ...                     ...           ...                       ...
# 1947412              931124           434 2015-09-15 08:45:00+00:00
# 1947413              306003           194 2014-06-01 16:33:00+00:00
# 1947414              421423          5103 2014-08-23 12:43:00+00:00
# 1947415              165481          5236 2014-01-25 01:54:00+00:00
# 1947416             1154192          1808 2016-04-08 07:11:00+00:00
#
#                                     start_station_name  start_station_id  \
# 0                                  Frank H Ogawa Plaza                 7
# ...

# %%
# %%sql
# SELECT start_station_name,
# COUNT(trip_id) AS total_trips
# FROM `bigquery-public-data.san_francisco_bikeshare.bikeshare_trips`
# WHERE EXTRACT (YEAR FROM start_date) = 2023
# GROUP BY start_station_name
# ORDER BY total_trips DESC;
# Out:
# UsageError: Cell magic `%%sql` not found.
